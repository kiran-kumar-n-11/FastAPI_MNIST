# %% [markdown]
# <h1 style="color:MAROON;text-align:center">BIG DATA LAB</h1>
# <h1 style="color:MAROON;text-align:center">ASSIGNMENT-6</h1>
# <h1 style="color:green;text-align:right">NAKKA KIRAN KUMAR</h1>
# <h1 style="color:green;text-align:right">ME20B117</h1>

# %% [markdown]
# * GITHUB LINK:

# %% [markdown]
# # FastAPI for MNIST Digit Prediction

# %% [markdown]
# ## a) 28x28 digit recognition

# %% [markdown]
# # Digits and Responses :

# %% [markdown]
# ## 1.

# %% [markdown]
# ![image-4.png](attachment:image-4.png)
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 2.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
# ![image.png](attachment:image.png)

# %% [markdown]
# ## b) Resize and Predict

# %% [markdown]
# # Correct Predictions:

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Incorrectly predictions:

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
# ![image.png](attachment:image.png)

# %% [markdown]
# # OBSERVATIONS:

# %% [markdown]
# * Model is predicting correctly only if the background is black and digit is written in white.
# * Model fails to predict digits correctly when the background colors are changed.
# * It is possibly due to different Grayscale values we get for different colors.
